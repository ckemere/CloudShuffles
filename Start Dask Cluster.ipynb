# %%
# see http://distributed.readthedocs.io/en/latest/local-cluster.html
from dask.distributed import Client
client = Client()
client
# Out:
# <Client: scheduler='tcp://127.0.0.1:38306' processes=32 cores=32>
